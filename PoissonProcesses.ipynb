# %%
import matplotlib.pyplot as plt
import random

# %%
2000/120
# Out:
# 16.666666666666668

# %%
random.expovariate(1/40)
# Out:
# 99.98914821462111

# %%
epochs = []
for i in range(2000):
    epochs.append(random.expovariate(2000/120))

# %%
epochs
# Out:
# [0.009766846781733939,
#  0.06161839294583421,
#  0.05431068405175542,
#  0.013992028499323902,
#  0.007768452125571277,
#  0.09208177029331001,
#  0.20292308573341333,
#  0.001780099517385655,
#  0.010668859093835862,
#  0.08003013330155809,
#  0.07033455729715886,
#  0.03165229316246653,
#  0.028840257599746254,
#  0.0018521964418935482,
#  0.051520097640531545,
#  0.05284612391765267,
#  0.050553002714648326,
#  0.2380998105561475,
#  0.03708483509449458,
#  0.09350806476220111,
#  0.05688980401916022,
#  0.06119896994723377,
#  0.0011139052566018703,
#  0.05571891731262567,
#  0.11907027750840408,
#  0.0026643273969226542,
#  0.05741437868712202,
#  0.03476536377544335,
#  0.034139225742995695,
#  0.09076406710309734,
#  0.002248056150129582,
#  0.009715970768325508,
#  0.04016245793462255,
#  0.05546049188592911,
#  0.0033609885922297744,
#  0.1312547692378919,
#  0.023865613172198097,
#  0.0033271912952662496,
#  0.12437196676523755,
#  0.08660002309410203,
# ...

# %%
sum(epochs)/2000
# Out:
# 0.05947018451490054

# %%
plt.plot(epochs)
plt.show()

# %%
def next_time(rate):
    return

# %%
interarrival=[]
while sum(interarrival) < 120:
    interarrival.append(random.expovariate(55.64166))
    
print(len(interarrival))
# Out:
# 6582

# %%
random.expovariate(55.641)
# Out:
# 0.029967128883610878
