# %%
import matplotlib.pyplot as plt
import random

# %%
2000/120
# Out:
# 16.666666666666668

# %%
random.expovariate(1/40)
# Out:
# 14.234746363126334

# %%
epochs = []
for i in range(2000):
    epochs.append(random.expovariate(2000/120))

# %%
epochs
# Out:
# [0.038188958937845636,
#  0.04567362240087953,
#  0.05444850366597455,
#  0.12245184891851517,
#  0.021401618833711233,
#  0.04579854492860237,
#  0.007110259002255721,
#  0.09667307525675924,
#  0.26409947205295187,
#  0.005945439891086437,
#  0.0009619366583299904,
#  0.035586872999171036,
#  0.07822278682639569,
#  0.049851819160784676,
#  0.02746496258797135,
#  0.09500878253483946,
#  0.036933884048088894,
#  0.06675183568157819,
#  0.11330647300814511,
#  0.04092748687582202,
#  0.023600054527223004,
#  0.015652970934719772,
#  0.03825444769790678,
#  0.13844929405473877,
#  0.012197723011375877,
#  0.07752151394217702,
#  0.005915189050950566,
#  0.010027365692421731,
#  0.03438234914761147,
#  0.19755828570598824,
#  0.028497102111501835,
#  0.06923819617151812,
#  0.04332967694683593,
#  0.0188858468385757,
#  0.018931863645574473,
#  0.07615518075291364,
#  0.06401821864732672,
#  0.004552828306070285,
#  0.07522022451356482,
#  0.03586838673166861,
# ...

# %%
sum(epochs)/2000
# Out:
# 0.05986339357761045

# %%
plt.plot(epochs)
plt.show()

# %%
def next_time(rate):
    return
